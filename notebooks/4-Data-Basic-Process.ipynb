# %% [markdown]
# # Preparação dos Dados

# %%
import pandas as pd
import numpy as np
import sys
import yaml
sys.path.append('../src/')

from utils.transformers import FixFeaturesType, FixFeaturesMissing

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

# %% [markdown]
# # Data

# %%
df = pd.read_csv('../data/raw/fraud_dataset_v2.csv', index_col=0)

# %%
df.head()
# Out:
#    a       b          c     d         e     f   g   h  \
# 0  4  0.7685   94436.24  20.0  0.444828   1.0  BR   5
# 1  4  0.7550    9258.50   1.0  0.000000  33.0  BR   0
# 2  4  0.7455  242549.09   3.0  0.000000  19.0  AR  23
# 3  4  0.7631   18923.90  50.0  0.482385  18.0  BR  23
# 4  2  0.7315    5728.68  15.0  0.000000   1.0  BR   2
#
#                                                    i            j         k  \
# 0  Máquininha Corta Barba Cabelo Peito Perna Pelo...  cat_8d714cd  0.883598
# 1  Avental Descartavel Manga Longa  - 50 Un. Tnt ...  cat_64b574b  0.376019
# 2  Bicicleta Mountain Fire Bird Rodado 29 Alumini...  cat_e9110c5  0.516368
# 3  Caneta Delineador Carimbo Olho Gatinho Longo 2...  cat_d06e653  0.154036
# 4           Resident Evil Operation Raccoon City Ps3  cat_6c4cfdc  0.855798
#
#         l       m  n    o  p     q       r    s                fecha   monto  \
# 0   240.0   102.0  1  NaN  N  0.40   94436    0  2020-03-27 11:51:16    5.64
# 1  4008.0     0.0  1    Y  N  0.02    9258    0  2020-04-15 19:58:08  124.71
# 2  1779.0    77.0  1  NaN  N  0.06  242549    0  2020-03-25 18:13:38  339.32
# 3  1704.0  1147.0  1  NaN  Y  0.98   18923  100  2020-04-16 16:03:10    3.54
# 4  1025.0   150.0  1  NaN  N  0.28    5728    0  2020-04-02 10:24:45    3.53
#
#    score  fraude
# 0   66.0       0
# 1   72.0       0
# 2   95.0       0
# 3    2.0       0
# 4   76.0       1

# %%
df_info = df.describe(include='all').T
df_info['tipo_coluna'] = df.dtypes
df_info['qtd_unicos'] = df.nunique()
df_info['tipo_final'] = df_info['qtd_unicos'].apply(lambda x: 'categorica' if x <= 70 else 'numerica')
df_info
# Out:
#            count  unique                                          top    freq  \
# a       250000.0     NaN                                          NaN     NaN
# b       228526.0     NaN                                          NaN     NaN
# c       228526.0     NaN                                          NaN     NaN
# d       249406.0     NaN                                          NaN     NaN
# e       250000.0     NaN                                          NaN     NaN
# f       249985.0     NaN                                          NaN     NaN
# g         249676      51                                           BR  185579
# h       250000.0     NaN                                          NaN     NaN
# i         250000  127804  Fone De Ouvido Sem Fio Xiaomi Airdots Preto     137
# j         250000    8324                                  cat_43b9c10    3697
# k       250000.0     NaN                                          NaN     NaN
# l       249985.0     NaN                                          NaN     NaN
# m       249406.0     NaN                                          NaN     NaN
# n       250000.0     NaN                                          NaN     NaN
# o          66372       2                                            Y   39899
# p         250000       2                                            Y  139856
# q       249406.0     NaN                                          NaN     NaN
# r       250000.0     NaN                                          NaN     NaN
# s       250000.0     NaN                                          NaN     NaN
# fecha     250000  145813                          2020-04-10 13:06:44       6
# monto   250000.0     NaN                                          NaN     NaN
# score   250000.0     NaN                                          NaN     NaN
# fraude  250000.0     NaN                                          NaN     NaN
#
#                  mean            std       min       25%       50%       75%  \
# a            3.710736       0.908846       0.0       3.0       4.0       4.0
# b            0.727647       0.132455       0.0    0.6778    0.7552    0.8061
# c       257801.060924  840623.502209      0.16  9714.785  43578.31  144911.6
# d           21.828208      20.088081      -1.0       3.0      15.0      49.0
# e            0.222844       2.650651       0.0       0.0  0.106154  0.283668
# f           51.288385      681.83091      -5.0       1.0       9.0      33.0
# g                 NaN            NaN       NaN       NaN       NaN       NaN
# h           14.259116      14.196752      -1.0       3.0       9.0      21.0
# i                 NaN            NaN       NaN       NaN       NaN       NaN
# j                 NaN            NaN       NaN       NaN       NaN       NaN
# k            0.497599       0.288246  0.000004   0.24691   0.49578  0.746415
# l         2325.054195    1711.840924      -1.0     931.0    1960.0    3469.0
# m          302.817615     321.876881      -1.0      44.0     197.0     463.0
# n            0.907152        0.29022       0.0       1.0       1.0       1.0
# o                 NaN            NaN       NaN       NaN       NaN       NaN
# p                 NaN            NaN       NaN       NaN       NaN       NaN
# q            0.426529       0.401747     -0.02      0.04      0.28      0.98
# r       258027.713156  803710.116875       0.0   11585.0   54604.0  216227.0
# s             55.9424      49.645722       0.0       0.0     100.0     100.0
# fecha             NaN            NaN       NaN       NaN       NaN       NaN
# monto        43.63878      88.564504      0.02     10.13     21.36     41.38
# score       47.225239      28.730558       0.0     22.28      47.0      72.0
# fraude       0.030008        0.17061       0.0       0.0       0.0       0.0
#
#                 max tipo_coluna  qtd_unicos  tipo_final
# a               5.0       int64           6  categorica
# b               1.0     float64        7672    numerica
# c       13878743.71     float64      135090    numerica
# d              51.0     float64          53  categorica
# e        833.333333     float64       43208    numerica
# f          145274.0     float64        1559    numerica
# g               NaN      object          51  categorica
# h              59.0       int64          61  categorica
# i               NaN      object      127804    numerica
# j               NaN      object        8324    numerica
# k          0.999995     float64      150000    numerica
# l            7544.0     float64        7389    numerica
# m            2225.0     float64        1882    numerica
# n               1.0       int64           2  categorica
# o               NaN      object           2  categorica
# p               NaN      object           2  categorica
# q               1.0     float64          52  categorica
# r        13878743.0       int64       91391    numerica
# s             100.0       int64           2  categorica
# fecha           NaN      object      145813    numerica
# monto       3696.35     float64       26333    numerica
# score         100.0     float64       10142    numerica
# fraude          1.0       int64           2  categorica

# %% [markdown]
# Avaliando as tabelas acima será necessário vamos realizar alguns ajustes de tipo e nulo.
# Ajustes de Tipo:
# - Ajustar coluna de data 'fecha' para tipo timestamp
#
# Ajuste de Nulos:
# - Ajustar colunas ['d', 'g', 'o', 'q'], para as colunas categóricas vou criar uma nova categoria indicando o nulo.
# - Ajustar colunas ['b', 'c', 'f', 'l', 'm'], para as colunas numéricas vou realizar uma substituição utilizando a mediana, para isso vou utilizar o conjunto de validação.
#
# Colunas com até 70 valores únicos foram definidas como colunas do tipo categórico e colunas com mais foram definidas como numéricas.

# %% [markdown]
# # Ajuste de Tipos

# %%
config_features = yaml.safe_load(open('../src/data/config/features.yml', 'r'))

# %%
fix_features = FixFeaturesType(config_features['fix_type_map'])

# %%
df_tmp = fix_features.transform(df)

# %% [markdown]
# # Ajuste de Missings

# %%
fix_missing = FixFeaturesMissing(config_features['fix_missing_numeric_features'],
                                 config_features['fix_missing_map'])

# %%
df_tmp = fix_missing.fit_transform(df_tmp)

# %%
df_tmp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 250000 entries, 0 to 249999
# Data columns (total 23 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   a       250000 non-null  int64
#  1   b       250000 non-null  float64
#  2   c       250000 non-null  float64
#  3   d       250000 non-null  float64
#  4   e       250000 non-null  float64
#  5   f       250000 non-null  float64
#  6   g       250000 non-null  object
#  7   h       250000 non-null  int64
#  8   i       250000 non-null  object
#  9   j       250000 non-null  object
#  10  k       250000 non-null  float64
#  11  l       250000 non-null  float64
#  12  m       250000 non-null  float64
#  13  n       250000 non-null  int64
#  14  o       250000 non-null  object
#  15  p       250000 non-null  object
#  16  q       250000 non-null  float64
#  17  r       250000 non-null  int64
#  18  s       250000 non-null  int64
#  19  fecha   250000 non-null  datetime64[s]
#  20  monto   250000 non-null  float64
#  21  score   250000 non-null  float64
#  22  fraude  250000 non-null  int64
# dtypes: datetime64[s](1), float64(11), int64(6), object(5)
# memory usage: 43.9+ MB
